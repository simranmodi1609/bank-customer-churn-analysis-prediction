# %% [markdown]
# ## Introduction
# ![image.png](attachment:1a9a0455-c3b5-4c33-950e-a5eaee449b31.png)

# %% [markdown]
# Churn prediction is the process of identifying which consumers are most likely to stop using a service or cancel their subscription. This is a critical factor for many businesses because acquiring new consumers costs more than retaining existing ones.
#
# This project focuses on the analysis and prediction of customer attrition for 'ABC Multinational Bank', a fictional bank, using customer data. The dataset for ABC Multinational Bank indicates which customers have left, stayed, or signed up for their service. Multiple important demographics are included for each customer that can help us identify at-risk customers, pain points, and actions to be taken.

# %% [markdown]
# ## About dataset

# %% [markdown]
# This dataset is for ABC Multinational bank with following columns:
#
# - customer_id, unused variable.
# - credit_score, used as input.
# - country, used as input.
# - gender, used as input.
# - age, used as input.
# - tenure, used as input.
# - balance, used as input.
# - products_number, used as input.
# - credit_card, used as input.
# - active_member, used as input.
# - estimated_salary, used as input.
# - churn, used as the target. 1 if the client has left the bank during some period or 0 if he/she has not.

# %% [markdown]
# Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from imblearn.over_sampling import SMOTE
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier

# %%
filename = "/Users/simranmodi/Downloads/Bank Customer Churn Prediction.csv"

# %% [markdown]
# ## Data preparation and cleaning

# %% [markdown]
# Loading the dataset as a pandas dataframe

# %%
df = pd.read_csv(filename)

# %% [markdown]
# Looking at the first 5 records

# %%
df.head().style.set_properties(**{"border" : "1px solid"})
# Out:
# <style type="text/css">
# #T_44b04_row0_col0, #T_44b04_row0_col1, #T_44b04_row0_col2, #T_44b04_row0_col3, #T_44b04_row0_col4, #T_44b04_row0_col5, #T_44b04_row0_col6, #T_44b04_row0_col7, #T_44b04_row0_col8, #T_44b04_row0_col9, #T_44b04_row0_col10, #T_44b04_row0_col11, #T_44b04_row1_col0, #T_44b04_row1_col1, #T_44b04_row1_col2, #T_44b04_row1_col3, #T_44b04_row1_col4, #T_44b04_row1_col5, #T_44b04_row1_col6, #T_44b04_row1_col7, #T_44b04_row1_col8, #T_44b04_row1_col9, #T_44b04_row1_col10, #T_44b04_row1_col11, #T_44b04_row2_col0, #T_44b04_row2_col1, #T_44b04_row2_col2, #T_44b04_row2_col3, #T_44b04_row2_col4, #T_44b04_row2_col5, #T_44b04_row2_col6, #T_44b04_row2_col7, #T_44b04_row2_col8, #T_44b04_row2_col9, #T_44b04_row2_col10, #T_44b04_row2_col11, #T_44b04_row3_col0, #T_44b04_row3_col1, #T_44b04_row3_col2, #T_44b04_row3_col3, #T_44b04_row3_col4, #T_44b04_row3_col5, #T_44b04_row3_col6, #T_44b04_row3_col7, #T_44b04_row3_col8, #T_44b04_row3_col9, #T_44b04_row3_col10, #T_44b04_row3_col11, #T_44b04_row4_col0, #T_44b04_row4_col1, #T_44b04_row4_col2, #T_44b04_row4_col3, #T_44b04_row4_col4, #T_44b04_row4_col5, #T_44b04_row4_col6, #T_44b04_row4_col7, #T_44b04_row4_col8, #T_44b04_row4_col9, #T_44b04_row4_col10, #T_44b04_row4_col11 {
#   border: 1px solid;
# }
# </style>
# <table id="T_44b04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44b04_level0_col0" class="col_heading level0 col0" >customer_id</th>
#       <th id="T_44b04_level0_col1" class="col_heading level0 col1" >credit_score</th>
#       <th id="T_44b04_level0_col2" class="col_heading level0 col2" >country</th>
#       <th id="T_44b04_level0_col3" class="col_heading level0 col3" >gender</th>
#       <th id="T_44b04_level0_col4" class="col_heading level0 col4" >age</th>
#       <th id="T_44b04_level0_col5" class="col_heading level0 col5" >tenure</th>
#       <th id="T_44b04_level0_col6" class="col_heading level0 col6" >balance</th>
#       <th id="T_44b04_level0_col7" class="col_heading level0 col7" >products_number</th>
#       <th id="T_44b04_level0_col8" class="col_heading level0 col8" >credit_card</th>
#       <th id="T_44b04_level0_col9" class="col_heading level0 col9" >active_member</th>
#       <th id="T_44b04_level0_col10" class="col_heading level0 col10" >estimated_salary</th>
#       <th id="T_44b04_level0_col11" class="col_heading level0 col11" >churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44b04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44b04_row0_col0" class="data row0 col0" >15634602</td>
#       <td id="T_44b04_row0_col1" class="data row0 col1" >619</td>
#       <td id="T_44b04_row0_col2" class="data row0 col2" >France</td>
#       <td id="T_44b04_row0_col3" class="data row0 col3" >Female</td>
#       <td id="T_44b04_row0_col4" class="data row0 col4" >42</td>
#       <td id="T_44b04_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_44b04_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_44b04_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_44b04_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_44b04_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_44b04_row0_col10" class="data row0 col10" >101348.880000</td>
#       <td id="T_44b04_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_44b04_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44b04_row1_col0" class="data row1 col0" >15647311</td>
#       <td id="T_44b04_row1_col1" class="data row1 col1" >608</td>
#       <td id="T_44b04_row1_col2" class="data row1 col2" >Spain</td>
#       <td id="T_44b04_row1_col3" class="data row1 col3" >Female</td>
#       <td id="T_44b04_row1_col4" class="data row1 col4" >41</td>
#       <td id="T_44b04_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_44b04_row1_col6" class="data row1 col6" >83807.860000</td>
#       <td id="T_44b04_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_44b04_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_44b04_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_44b04_row1_col10" class="data row1 col10" >112542.580000</td>
#       <td id="T_44b04_row1_col11" class="data row1 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_44b04_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44b04_row2_col0" class="data row2 col0" >15619304</td>
#       <td id="T_44b04_row2_col1" class="data row2 col1" >502</td>
#       <td id="T_44b04_row2_col2" class="data row2 col2" >France</td>
#       <td id="T_44b04_row2_col3" class="data row2 col3" >Female</td>
#       <td id="T_44b04_row2_col4" class="data row2 col4" >42</td>
#       <td id="T_44b04_row2_col5" class="data row2 col5" >8</td>
#       <td id="T_44b04_row2_col6" class="data row2 col6" >159660.800000</td>
#       <td id="T_44b04_row2_col7" class="data row2 col7" >3</td>
#       <td id="T_44b04_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_44b04_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_44b04_row2_col10" class="data row2 col10" >113931.570000</td>
#       <td id="T_44b04_row2_col11" class="data row2 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_44b04_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_44b04_row3_col0" class="data row3 col0" >15701354</td>
#       <td id="T_44b04_row3_col1" class="data row3 col1" >699</td>
#       <td id="T_44b04_row3_col2" class="data row3 col2" >France</td>
#       <td id="T_44b04_row3_col3" class="data row3 col3" >Female</td>
#       <td id="T_44b04_row3_col4" class="data row3 col4" >39</td>
#       <td id="T_44b04_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_44b04_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_44b04_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_44b04_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_44b04_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_44b04_row3_col10" class="data row3 col10" >93826.630000</td>
#       <td id="T_44b04_row3_col11" class="data row3 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_44b04_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_44b04_row4_col0" class="data row4 col0" >15737888</td>
#       <td id="T_44b04_row4_col1" class="data row4 col1" >850</td>
#       <td id="T_44b04_row4_col2" class="data row4 col2" >Spain</td>
#       <td id="T_44b04_row4_col3" class="data row4 col3" >Female</td>
#       <td id="T_44b04_row4_col4" class="data row4 col4" >43</td>
#       <td id="T_44b04_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_44b04_row4_col6" class="data row4 col6" >125510.820000</td>
#       <td id="T_44b04_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_44b04_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_44b04_row4_col9" class="data row4 col9" >1</td>
#       <td id="T_44b04_row4_col10" class="data row4 col10" >79084.100000</td>
#       <td id="T_44b04_row4_col11" class="data row4 col11" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Looking at 5 random records

# %%
df.sample(5).style.set_properties(**{"border" : "1px solid"})
# Out:
# <style type="text/css">
# #T_22019_row0_col0, #T_22019_row0_col1, #T_22019_row0_col2, #T_22019_row0_col3, #T_22019_row0_col4, #T_22019_row0_col5, #T_22019_row0_col6, #T_22019_row0_col7, #T_22019_row0_col8, #T_22019_row0_col9, #T_22019_row0_col10, #T_22019_row0_col11, #T_22019_row1_col0, #T_22019_row1_col1, #T_22019_row1_col2, #T_22019_row1_col3, #T_22019_row1_col4, #T_22019_row1_col5, #T_22019_row1_col6, #T_22019_row1_col7, #T_22019_row1_col8, #T_22019_row1_col9, #T_22019_row1_col10, #T_22019_row1_col11, #T_22019_row2_col0, #T_22019_row2_col1, #T_22019_row2_col2, #T_22019_row2_col3, #T_22019_row2_col4, #T_22019_row2_col5, #T_22019_row2_col6, #T_22019_row2_col7, #T_22019_row2_col8, #T_22019_row2_col9, #T_22019_row2_col10, #T_22019_row2_col11, #T_22019_row3_col0, #T_22019_row3_col1, #T_22019_row3_col2, #T_22019_row3_col3, #T_22019_row3_col4, #T_22019_row3_col5, #T_22019_row3_col6, #T_22019_row3_col7, #T_22019_row3_col8, #T_22019_row3_col9, #T_22019_row3_col10, #T_22019_row3_col11, #T_22019_row4_col0, #T_22019_row4_col1, #T_22019_row4_col2, #T_22019_row4_col3, #T_22019_row4_col4, #T_22019_row4_col5, #T_22019_row4_col6, #T_22019_row4_col7, #T_22019_row4_col8, #T_22019_row4_col9, #T_22019_row4_col10, #T_22019_row4_col11 {
#   border: 1px solid;
# }
# </style>
# <table id="T_22019">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22019_level0_col0" class="col_heading level0 col0" >customer_id</th>
#       <th id="T_22019_level0_col1" class="col_heading level0 col1" >credit_score</th>
#       <th id="T_22019_level0_col2" class="col_heading level0 col2" >country</th>
#       <th id="T_22019_level0_col3" class="col_heading level0 col3" >gender</th>
#       <th id="T_22019_level0_col4" class="col_heading level0 col4" >age</th>
#       <th id="T_22019_level0_col5" class="col_heading level0 col5" >tenure</th>
#       <th id="T_22019_level0_col6" class="col_heading level0 col6" >balance</th>
#       <th id="T_22019_level0_col7" class="col_heading level0 col7" >products_number</th>
#       <th id="T_22019_level0_col8" class="col_heading level0 col8" >credit_card</th>
#       <th id="T_22019_level0_col9" class="col_heading level0 col9" >active_member</th>
#       <th id="T_22019_level0_col10" class="col_heading level0 col10" >estimated_salary</th>
#       <th id="T_22019_level0_col11" class="col_heading level0 col11" >churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22019_level0_row0" class="row_heading level0 row0" >1343</th>
#       <td id="T_22019_row0_col0" class="data row0 col0" >15645778</td>
#       <td id="T_22019_row0_col1" class="data row0 col1" >670</td>
#       <td id="T_22019_row0_col2" class="data row0 col2" >Spain</td>
#       <td id="T_22019_row0_col3" class="data row0 col3" >Male</td>
#       <td id="T_22019_row0_col4" class="data row0 col4" >42</td>
#       <td id="T_22019_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_22019_row0_col6" class="data row0 col6" >81589.040000</td>
#       <td id="T_22019_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_22019_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_22019_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_22019_row0_col10" class="data row0 col10" >188227.800000</td>
#       <td id="T_22019_row0_col11" class="data row0 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_22019_level0_row1" class="row_heading level0 row1" >3480</th>
#       <td id="T_22019_row1_col0" class="data row1 col0" >15807993</td>
#       <td id="T_22019_row1_col1" class="data row1 col1" >588</td>
#       <td id="T_22019_row1_col2" class="data row1 col2" >Germany</td>
#       <td id="T_22019_row1_col3" class="data row1 col3" >Female</td>
#       <td id="T_22019_row1_col4" class="data row1 col4" >30</td>
#       <td id="T_22019_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_22019_row1_col6" class="data row1 col6" >110148.490000</td>
#       <td id="T_22019_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_22019_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_22019_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_22019_row1_col10" class="data row1 col10" >5790.900000</td>
#       <td id="T_22019_row1_col11" class="data row1 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_22019_level0_row2" class="row_heading level0 row2" >4269</th>
#       <td id="T_22019_row2_col0" class="data row2 col0" >15580252</td>
#       <td id="T_22019_row2_col1" class="data row2 col1" >748</td>
#       <td id="T_22019_row2_col2" class="data row2 col2" >France</td>
#       <td id="T_22019_row2_col3" class="data row2 col3" >Male</td>
#       <td id="T_22019_row2_col4" class="data row2 col4" >44</td>
#       <td id="T_22019_row2_col5" class="data row2 col5" >4</td>
#       <td id="T_22019_row2_col6" class="data row2 col6" >112610.770000</td>
#       <td id="T_22019_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_22019_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_22019_row2_col9" class="data row2 col9" >1</td>
#       <td id="T_22019_row2_col10" class="data row2 col10" >2048.550000</td>
#       <td id="T_22019_row2_col11" class="data row2 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_22019_level0_row3" class="row_heading level0 row3" >3389</th>
#       <td id="T_22019_row3_col0" class="data row3 col0" >15724863</td>
#       <td id="T_22019_row3_col1" class="data row3 col1" >420</td>
#       <td id="T_22019_row3_col2" class="data row3 col2" >Spain</td>
#       <td id="T_22019_row3_col3" class="data row3 col3" >Female</td>
#       <td id="T_22019_row3_col4" class="data row3 col4" >55</td>
#       <td id="T_22019_row3_col5" class="data row3 col5" >4</td>
#       <td id="T_22019_row3_col6" class="data row3 col6" >91893.320000</td>
#       <td id="T_22019_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_22019_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_22019_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_22019_row3_col10" class="data row3 col10" >144870.280000</td>
#       <td id="T_22019_row3_col11" class="data row3 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_22019_level0_row4" class="row_heading level0 row4" >5142</th>
#       <td id="T_22019_row4_col0" class="data row4 col0" >15778526</td>
#       <td id="T_22019_row4_col1" class="data row4 col1" >719</td>
#       <td id="T_22019_row4_col2" class="data row4 col2" >Spain</td>
#       <td id="T_22019_row4_col3" class="data row4 col3" >Female</td>
#       <td id="T_22019_row4_col4" class="data row4 col4" >48</td>
#       <td id="T_22019_row4_col5" class="data row4 col5" >5</td>
#       <td id="T_22019_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_22019_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_22019_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_22019_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_22019_row4_col10" class="data row4 col10" >78563.660000</td>
#       <td id="T_22019_row4_col11" class="data row4 col11" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Looking at some general information regarding the dataframe

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
df.describe().T.style.set_properties(**{"border" : "1px solid"})
# Out:
# <style type="text/css">
# #T_2603d_row0_col0, #T_2603d_row0_col1, #T_2603d_row0_col2, #T_2603d_row0_col3, #T_2603d_row0_col4, #T_2603d_row0_col5, #T_2603d_row0_col6, #T_2603d_row0_col7, #T_2603d_row1_col0, #T_2603d_row1_col1, #T_2603d_row1_col2, #T_2603d_row1_col3, #T_2603d_row1_col4, #T_2603d_row1_col5, #T_2603d_row1_col6, #T_2603d_row1_col7, #T_2603d_row2_col0, #T_2603d_row2_col1, #T_2603d_row2_col2, #T_2603d_row2_col3, #T_2603d_row2_col4, #T_2603d_row2_col5, #T_2603d_row2_col6, #T_2603d_row2_col7, #T_2603d_row3_col0, #T_2603d_row3_col1, #T_2603d_row3_col2, #T_2603d_row3_col3, #T_2603d_row3_col4, #T_2603d_row3_col5, #T_2603d_row3_col6, #T_2603d_row3_col7, #T_2603d_row4_col0, #T_2603d_row4_col1, #T_2603d_row4_col2, #T_2603d_row4_col3, #T_2603d_row4_col4, #T_2603d_row4_col5, #T_2603d_row4_col6, #T_2603d_row4_col7, #T_2603d_row5_col0, #T_2603d_row5_col1, #T_2603d_row5_col2, #T_2603d_row5_col3, #T_2603d_row5_col4, #T_2603d_row5_col5, #T_2603d_row5_col6, #T_2603d_row5_col7, #T_2603d_row6_col0, #T_2603d_row6_col1, #T_2603d_row6_col2, #T_2603d_row6_col3, #T_2603d_row6_col4, #T_2603d_row6_col5, #T_2603d_row6_col6, #T_2603d_row6_col7, #T_2603d_row7_col0, #T_2603d_row7_col1, #T_2603d_row7_col2, #T_2603d_row7_col3, #T_2603d_row7_col4, #T_2603d_row7_col5, #T_2603d_row7_col6, #T_2603d_row7_col7, #T_2603d_row8_col0, #T_2603d_row8_col1, #T_2603d_row8_col2, #T_2603d_row8_col3, #T_2603d_row8_col4, #T_2603d_row8_col5, #T_2603d_row8_col6, #T_2603d_row8_col7, #T_2603d_row9_col0, #T_2603d_row9_col1, #T_2603d_row9_col2, #T_2603d_row9_col3, #T_2603d_row9_col4, #T_2603d_row9_col5, #T_2603d_row9_col6, #T_2603d_row9_col7 {
#   border: 1px solid;
# }
# </style>
# <table id="T_2603d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2603d_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_2603d_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_2603d_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_2603d_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_2603d_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_2603d_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_2603d_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_2603d_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2603d_level0_row0" class="row_heading level0 row0" >customer_id</th>
#       <td id="T_2603d_row0_col0" class="data row0 col0" >10000.000000</td>
#       <td id="T_2603d_row0_col1" class="data row0 col1" >15690940.569400</td>
#       <td id="T_2603d_row0_col2" class="data row0 col2" >71936.186123</td>
#       <td id="T_2603d_row0_col3" class="data row0 col3" >15565701.000000</td>
#       <td id="T_2603d_row0_col4" class="data row0 col4" >15628528.250000</td>
#       <td id="T_2603d_row0_col5" class="data row0 col5" >15690738.000000</td>
#       <td id="T_2603d_row0_col6" class="data row0 col6" >15753233.750000</td>
#       <td id="T_2603d_row0_col7" class="data row0 col7" >15815690.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2603d_level0_row1" class="row_heading level0 row1" >credit_score</th>
#       <td id="T_2603d_row1_col0" class="data row1 col0" >10000.000000</td>
#       <td id="T_2603d_row1_col1" class="data row1 col1" >650.528800</td>
#       <td id="T_2603d_row1_col2" class="data row1 col2" >96.653299</td>
#       <td id="T_2603d_row1_col3" class="data row1 col3" >350.000000</td>
#       <td id="T_2603d_row1_col4" class="data row1 col4" >584.000000</td>
#       <td id="T_2603d_row1_col5" class="data row1 col5" >652.000000</td>
#       <td id="T_2603d_row1_col6" class="data row1 col6" >718.000000</td>
#       <td id="T_2603d_row1_col7" class="data row1 col7" >850.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2603d_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_2603d_row2_col0" class="data row2 col0" >10000.000000</td>
#       <td id="T_2603d_row2_col1" class="data row2 col1" >38.921800</td>
#       <td id="T_2603d_row2_col2" class="data row2 col2" >10.487806</td>
#       <td id="T_2603d_row2_col3" class="data row2 col3" >18.000000</td>
#       <td id="T_2603d_row2_col4" class="data row2 col4" >32.000000</td>
#       <td id="T_2603d_row2_col5" class="data row2 col5" >37.000000</td>
#       <td id="T_2603d_row2_col6" class="data row2 col6" >44.000000</td>
#       <td id="T_2603d_row2_col7" class="data row2 col7" >92.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2603d_level0_row3" class="row_heading level0 row3" >tenure</th>
#       <td id="T_2603d_row3_col0" class="data row3 col0" >10000.000000</td>
#       <td id="T_2603d_row3_col1" class="data row3 col1" >5.012800</td>
#       <td id="T_2603d_row3_col2" class="data row3 col2" >2.892174</td>
#       <td id="T_2603d_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_2603d_row3_col4" class="data row3 col4" >3.000000</td>
#       <td id="T_2603d_row3_col5" class="data row3 col5" >5.000000</td>
#       <td id="T_2603d_row3_col6" class="data row3 col6" >7.000000</td>
#       <td id="T_2603d_row3_col7" class="data row3 col7" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2603d_level0_row4" class="row_heading level0 row4" >balance</th>
#       <td id="T_2603d_row4_col0" class="data row4 col0" >10000.000000</td>
#       <td id="T_2603d_row4_col1" class="data row4 col1" >76485.889288</td>
#       <td id="T_2603d_row4_col2" class="data row4 col2" >62397.405202</td>
#       <td id="T_2603d_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_2603d_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_2603d_row4_col5" class="data row4 col5" >97198.540000</td>
#       <td id="T_2603d_row4_col6" class="data row4 col6" >127644.240000</td>
#       <td id="T_2603d_row4_col7" class="data row4 col7" >250898.090000</td>
#     </tr>
#     <tr>
#       <th id="T_2603d_level0_row5" class="row_heading level0 row5" >products_number</th>
#       <td id="T_2603d_row5_col0" class="data row5 col0" >10000.000000</td>
#       <td id="T_2603d_row5_col1" class="data row5 col1" >1.530200</td>
#       <td id="T_2603d_row5_col2" class="data row5 col2" >0.581654</td>
#       <td id="T_2603d_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_2603d_row5_col4" class="data row5 col4" >1.000000</td>
#       <td id="T_2603d_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_2603d_row5_col6" class="data row5 col6" >2.000000</td>
#       <td id="T_2603d_row5_col7" class="data row5 col7" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2603d_level0_row6" class="row_heading level0 row6" >credit_card</th>
#       <td id="T_2603d_row6_col0" class="data row6 col0" >10000.000000</td>
#       <td id="T_2603d_row6_col1" class="data row6 col1" >0.705500</td>
#       <td id="T_2603d_row6_col2" class="data row6 col2" >0.455840</td>
#       <td id="T_2603d_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_2603d_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_2603d_row6_col5" class="data row6 col5" >1.000000</td>
#       <td id="T_2603d_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_2603d_row6_col7" class="data row6 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2603d_level0_row7" class="row_heading level0 row7" >active_member</th>
#       <td id="T_2603d_row7_col0" class="data row7 col0" >10000.000000</td>
#       <td id="T_2603d_row7_col1" class="data row7 col1" >0.515100</td>
#       <td id="T_2603d_row7_col2" class="data row7 col2" >0.499797</td>
#       <td id="T_2603d_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_2603d_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_2603d_row7_col5" class="data row7 col5" >1.000000</td>
#       <td id="T_2603d_row7_col6" class="data row7 col6" >1.000000</td>
#       <td id="T_2603d_row7_col7" class="data row7 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2603d_level0_row8" class="row_heading level0 row8" >estimated_salary</th>
#       <td id="T_2603d_r

# %%
df.nunique()
# Out:
# customer_id         10000
# credit_score          460
# country                 3
# gender                  2
# age                    70
# tenure                 11
# balance              6382
# products_number         4
# credit_card             2
# active_member           2
# estimated_salary     9999
# churn                   2
# dtype: int64

# %% [markdown]
# Checking for missing values

# %%
df.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %% [markdown]
# There are no missing values

# %% [markdown]
# Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates

# %% [markdown]
# Checking for data imbalance

# %%
df['churn'].value_counts()
# Out:
# churn
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %% [markdown]
# Data is highly imbalanced

# %% [markdown]
# Creating a copy of the base data for manipulation and processing

# %%
df_cp = df.copy()

# %% [markdown]
# Removing 'customer_id' since it is not required

# %%
df_cp = df_cp.drop('customer_id',axis=1)
df_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      10000 non-null  int64
#  1   country           10000 non-null  object
#  2   gender            10000 non-null  object
#  3   age               10000 non-null  int64
#  4   tenure            10000 non-null  int64
#  5   balance           10000 non-null  float64
#  6   products_number   10000 non-null  int64
#  7   credit_card       10000 non-null  int64
#  8   active_member     10000 non-null  int64
#  9   estimated_salary  10000 non-null  float64
#  10  churn             10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %% [markdown]
# ## Exploratory data analysis and visualization

# %% [markdown]
# Analyzing the correlation heatmap

# %%
c_map=sns.color_palette("rocket_r", as_cmap=True)
correlation = df_cp.corr(numeric_only=True).round(2)
plt.figure(figsize = (12,8))
sns.heatmap(correlation, annot = True, cmap = c_map)
plt.show()

# %%
abs(correlation['churn']).sort_values(ascending=False)
# Out:
# churn               1.00
# age                 0.29
# active_member       0.16
# balance             0.12
# products_number     0.05
# credit_score        0.03
# tenure              0.01
# credit_card         0.01
# estimated_salary    0.01
# Name: churn, dtype: float64

# %% [markdown]
# 'age', 'active_member', 'balance' show a relatively stronger correlation with the outcome of churn

# %% [markdown]
# Plotting a pie chart showing the percentage of churned and retained customers

# %%
colors=sns.color_palette("tab20")
labels = 'Churned', 'Retained'
sizes = [df_cp.churn[df_cp['churn']==1].count(), df_cp.churn[df_cp['churn']==0].count()]
explode = (0, 0.1)
plt.figure(figsize=(7,7))
plt.pie(sizes, explode=explode, labels=labels, textprops={'fontsize': 10}, autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
plt.show()

# %% [markdown]
# Analyzing the distribution of numerical features

# %%
plt.figure(figsize=(12,20))

plt.subplot(4,1,1)
sns.histplot(df_cp, x='credit_score', hue='churn', kde=True, palette=[colors[0], colors[2]])
plt.xlabel('credit_score', fontsize=12, color=colors[0])
plt.ylabel('count', fontsize=12, color=colors[0])

plt.subplot(4,1,2)
sns.histplot(df_cp, x='age', hue='churn', kde=True, palette=[colors[0], colors[2]])
plt.xlabel('age', fontsize=12, color=colors[0])
plt.ylabel('count', fontsize=12, color=colors[0])

plt.subplot(4,1,3)
sns.histplot(df_cp, x='balance', hue='churn', kde=True, palette=[colors[0], colors[2]])
plt.xlabel('balance', fontsize=12, color=colors[0])
plt.ylabel('count', fontsize=12, color=colors[0])

plt.subplot(4,1,4)
sns.histplot(df_cp, x='estimated_salary', hue='churn', kde=True, palette=[colors[0], colors[2]])
plt.xlabel('estimated_salary', fontsize=12, color=colors[0])
plt.ylabel('count', fontsize=12, color=colors[0])

plt.show()
# Out:
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# - Most people have a credit score between 600 and 700.
# - Most non-churners are 30-40 years old, while most churners are 40-60 years old.
# - There are many people who have no bank balance.

# %% [markdown]
# Analyzing the categorical features

# %%
plt.figure(figsize=(12,10))

plt.subplot(2,2,1)
cplot = sns.countplot(data=df_cp, x='country', hue='churn', order=df_cp['country'].value_counts().index, palette=colors)
plt.xlabel('country', fontsize=12, color=colors[0])
plt.ylabel('count', fontsize=12, color=colors[0])
for x in cplot.patches:
  cplot.text (x.get_x() + x.get_width()  / 2, x.get_height()+ 0.75, x.get_height(), horizontalalignment='center', fontsize = 10)

plt.subplot(2,2,2)
cplot = sns.countplot(data=df_cp, x='gender', hue='churn', order=df_cp['gender'].value_counts().index, palette=colors)
plt.xlabel('gender', fontsize=12, color=colors[0])
plt.ylabel('count', fontsize=12, color=colors[0])
for x in cplot.patches:
  cplot.text (x.get_x() + x.get_width()  / 2, x.get_height()+ 0.75, x.get_height(), horizontalalignment='center', fontsize = 10)

plt.subplot(2,2,3)
cplot = sns.countplot(data=df_cp, x='credit_card', hue='churn', order=df_cp['credit_card'].value_counts().index, palette=colors)
plt.xlabel('credit_card', fontsize=12, color=colors[0])
plt.ylabel('count', fontsize=12, color=colors[0])
for x in cplot.patches:
  cplot.text (x.get_x() + x.get_width()  / 2, x.get_height()+ 0.75, x.get_height(), horizontalalignment='center', fontsize = 10)

plt.subplot(2,2,4)
cplot = sns.countplot(data=df_cp, x='active_member', hue='churn', order=df_cp['active_member'].value_counts().index, palette=colors)
plt.xlabel('active_member', fontsize=12, color=colors[0])
plt.ylabel('count', fontsize=12, color=colors[0])
for x in cplot.patches:
  cplot.text (x.get_x() + x.get_width()  / 2, x.get_height()+ 0.75, x.get_height(), horizontalalignment='center', fontsize = 10)

plt.show()
# Out:
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# - Germany has the highest number of churners.
# - Spain has relatively few churners.
# - Female churners > Male churners.
# - Most churners have credit cards but are not active members.

# %%
plt.figure(figsize=(14,5))

cplot = sns.countplot(data=df_cp, x='products_number', hue='churn', palette=colors)
plt.xlabel('products_number', fontsize=12, color=colors[0])
plt.ylabel('count', fontsize=12, color=colors[0])
for x in cplot.patches:
  cplot.text (x.get_x() + x.get_width()  / 2, x.get_height()+ 0.75, x.get_height(), horizontalalignment='center', fontsize = 10)

plt.show()
# Out:
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# - Most customers have only 1 or 2 products.
# - Most of the non-churners have 2 products.
# - Most of the churners have 1 product.
# - Customers having 3,4 products are mostly churners.

# %%
plt.figure(figsize=(14,5))

cplot = sns.countplot(data=df_cp, x='tenure', hue='churn', palette=colors)
plt.xlabel('tenure', fontsize=12, color=colors[0])
plt.ylabel('count', fontsize=12, color=colors[0])
for x in cplot.patches:
  cplot.text (x.get_x() + x.get_width()  / 2, x.get_height()+ 0.75, x.get_height(), horizontalalignment='center', fontsize = 9)

plt.show()
# Out:
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# - Most churners have a tenure of 1 year.
# - Only a few customers have a tenure of 0 or 10 years.

# %%
plt.figure(figsize=(10,5))

sns.scatterplot(data=df_cp, x='estimated_salary', y='credit_score', hue='churn', palette=[colors[0], colors[2]])
plt.xlabel('estimated_salary', fontsize=12, color=colors[0])
plt.ylabel('credit_score', fontsize=12, color=colors[0])
plt.xticks(rotation=45)

plt.show()
# Out:
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Customers with a credit score < 400 are mostly churners

# %%
plt.figure(figsize=(10,5))

sns.scatterplot(data=df_cp, x='age', y='estimated_salary', hue='churn', palette=[colors[0], colors[2]])
plt.xlabel('age', fontsize=12, color=colors[0])
plt.ylabel('estimate_salary', fontsize=12, color=colors[0])

plt.show()
# Out:
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/simranmodi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Most churners lie within the age group of 40-60 years

# %% [markdown]
# ## Data pre-processing

# %%
dfEnc=df_cp.copy()

# %% [markdown]
# Encoding 'gender', 'country'

# %%
dfEnc["gender"] = LabelEncoder().fit_transform(dfEnc["gender"])
dfEnc["country"] = LabelEncoder().fit_transform(dfEnc["country"])

# %% [markdown]
# Separating dependent and independent variables

# %%
X=dfEnc.drop('churn',axis=1)
X.head().style.set_properties(**{"border" : "1px solid"})
# Out:
# <style type="text/css">
# #T_a5f76_row0_col0, #T_a5f76_row0_col1, #T_a5f76_row0_col2, #T_a5f76_row0_col3, #T_a5f76_row0_col4, #T_a5f76_row0_col5, #T_a5f76_row0_col6, #T_a5f76_row0_col7, #T_a5f76_row0_col8, #T_a5f76_row0_col9, #T_a5f76_row1_col0, #T_a5f76_row1_col1, #T_a5f76_row1_col2, #T_a5f76_row1_col3, #T_a5f76_row1_col4, #T_a5f76_row1_col5, #T_a5f76_row1_col6, #T_a5f76_row1_col7, #T_a5f76_row1_col8, #T_a5f76_row1_col9, #T_a5f76_row2_col0, #T_a5f76_row2_col1, #T_a5f76_row2_col2, #T_a5f76_row2_col3, #T_a5f76_row2_col4, #T_a5f76_row2_col5, #T_a5f76_row2_col6, #T_a5f76_row2_col7, #T_a5f76_row2_col8, #T_a5f76_row2_col9, #T_a5f76_row3_col0, #T_a5f76_row3_col1, #T_a5f76_row3_col2, #T_a5f76_row3_col3, #T_a5f76_row3_col4, #T_a5f76_row3_col5, #T_a5f76_row3_col6, #T_a5f76_row3_col7, #T_a5f76_row3_col8, #T_a5f76_row3_col9, #T_a5f76_row4_col0, #T_a5f76_row4_col1, #T_a5f76_row4_col2, #T_a5f76_row4_col3, #T_a5f76_row4_col4, #T_a5f76_row4_col5, #T_a5f76_row4_col6, #T_a5f76_row4_col7, #T_a5f76_row4_col8, #T_a5f76_row4_col9 {
#   border: 1px solid;
# }
# </style>
# <table id="T_a5f76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5f76_level0_col0" class="col_heading level0 col0" >credit_score</th>
#       <th id="T_a5f76_level0_col1" class="col_heading level0 col1" >country</th>
#       <th id="T_a5f76_level0_col2" class="col_heading level0 col2" >gender</th>
#       <th id="T_a5f76_level0_col3" class="col_heading level0 col3" >age</th>
#       <th id="T_a5f76_level0_col4" class="col_heading level0 col4" >tenure</th>
#       <th id="T_a5f76_level0_col5" class="col_heading level0 col5" >balance</th>
#       <th id="T_a5f76_level0_col6" class="col_heading level0 col6" >products_number</th>
#       <th id="T_a5f76_level0_col7" class="col_heading level0 col7" >credit_card</th>
#       <th id="T_a5f76_level0_col8" class="col_heading level0 col8" >active_member</th>
#       <th id="T_a5f76_level0_col9" class="col_heading level0 col9" >estimated_salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5f76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5f76_row0_col0" class="data row0 col0" >619</td>
#       <td id="T_a5f76_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_a5f76_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_a5f76_row0_col3" class="data row0 col3" >42</td>
#       <td id="T_a5f76_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_a5f76_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_a5f76_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_a5f76_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_a5f76_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_a5f76_row0_col9" class="data row0 col9" >101348.880000</td>
#     </tr>
#     <tr>
#       <th id="T_a5f76_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5f76_row1_col0" class="data row1 col0" >608</td>
#       <td id="T_a5f76_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_a5f76_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_a5f76_row1_col3" class="data row1 col3" >41</td>
#       <td id="T_a5f76_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_a5f76_row1_col5" class="data row1 col5" >83807.860000</td>
#       <td id="T_a5f76_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_a5f76_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_a5f76_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_a5f76_row1_col9" class="data row1 col9" >112542.580000</td>
#     </tr>
#     <tr>
#       <th id="T_a5f76_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5f76_row2_col0" class="data row2 col0" >502</td>
#       <td id="T_a5f76_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_a5f76_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_a5f76_row2_col3" class="data row2 col3" >42</td>
#       <td id="T_a5f76_row2_col4" class="data row2 col4" >8</td>
#       <td id="T_a5f76_row2_col5" class="data row2 col5" >159660.800000</td>
#       <td id="T_a5f76_row2_col6" class="data row2 col6" >3</td>
#       <td id="T_a5f76_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_a5f76_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_a5f76_row2_col9" class="data row2 col9" >113931.570000</td>
#     </tr>
#     <tr>
#       <th id="T_a5f76_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5f76_row3_col0" class="data row3 col0" >699</td>
#       <td id="T_a5f76_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_a5f76_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_a5f76_row3_col3" class="data row3 col3" >39</td>
#       <td id="T_a5f76_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_a5f76_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_a5f76_row3_col6" class="data row3 col6" >2</td>
#       <td id="T_a5f76_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_a5f76_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_a5f76_row3_col9" class="data row3 col9" >93826.630000</td>
#     </tr>
#     <tr>
#       <th id="T_a5f76_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5f76_row4_col0" class="data row4 col0" >850</td>
#       <td id="T_a5f76_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_a5f76_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_a5f76_row4_col3" class="data row4 col3" >43</td>
#       <td id="T_a5f76_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_a5f76_row4_col5" class="data row4 col5" >125510.820000</td>
#       <td id="T_a5f76_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_a5f76_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_a5f76_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_a5f76_row4_col9" class="data row4 col9" >79084.100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
Y=dfEnc['churn']
Y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: churn, dtype: int64

# %% [markdown]
# Using SMOTE to handle data imbalance

# %%
X_bal,Y_bal=SMOTE().fit_resample(X,Y)

# %%
Y_bal.value_counts()
# Out:
# churn
# 1    7963
# 0    7963
# Name: count, dtype: int64

# %% [markdown]
# Train-test split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_bal,Y_bal,test_size=0.2,random_state=42)

# %%
print("X_bal shape : ", X_bal.shape)
print("X_train shape : ", X_train.shape)
print("X_test shape : ", X_test.shape)
print("Y_bal shape : ", Y_bal.shape)
print("Y_train shape : ", Y_train.shape)
print("Y_test shape : ", Y_test.shape)
# Out:
# X_bal shape :  (15926, 10)
# X_train shape :  (12740, 10)
# X_test shape :  (3186, 10)
# Y_bal shape :  (15926,)
# Y_train shape :  (12740,)
# Y_test shape :  (3186,)

# %% [markdown]
# ## Model building

# %% [markdown]
# Building the classifier

# %%
rf = RandomForestClassifier(n_jobs=-1, verbose=2)

# %%
rf.fit(X_train, Y_train)
# Out:
# building tree 1 of 100building tree 2 of 100
#
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    0.1s
# building tree 71 of 100building tree 72 of 100
#
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.3s finished
# RandomForestClassifier(n_jobs=-1, verbose=2)

# %%
Y_pred = rf.predict(X_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished

# %% [markdown]
# Classification report

# %%
print(metrics.classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1633
#            1       0.84      0.87      0.86      1553
#
#     accuracy                           0.86      3186
#    macro avg       0.86      0.86      0.86      3186
# weighted avg       0.86      0.86      0.86      3186

# %% [markdown]
# Confusion matrix

# %%
cf_matrix = metrics.confusion_matrix(Y_test, Y_pred)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
plt.figure(figsize=(6,5))
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap=c_map)
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ')
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
plt.show()

# %% [markdown]
# ROC curve and AUC

# %%
fpr, tpr, threshold = metrics.roc_curve(Y_test, Y_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# Predicting churn for a sample input

# %%
sample = [[400, 1, 0, 50, 3, 500.00, 1, 1, 0, 200000.00]]
sample_df = pd.DataFrame(sample, columns=['credit_score', 'country', 'gender', 'age', 'tenure', 'balance'	,'products_number' ,'credit_card',	'active_member'	,'estimated_salary'])
print("Sample input:- \n")
display(sample_df.style.set_properties(**{"border" : "1px solid"}))
print("\n\nPredicted value:- \n")
pred = rf.predict(sample_df)
if pred[0] == 1:
  print("Customer is likely to leave\n")
else:
  print("Customer is likely to stay\n")
# Out:
# Sample input:-
# <style type="text/css">
# #T_8a7f7_row0_col0, #T_8a7f7_row0_col1, #T_8a7f7_row0_col2, #T_8a7f7_row0_col3, #T_8a7f7_row0_col4, #T_8a7f7_row0_col5, #T_8a7f7_row0_col6, #T_8a7f7_row0_col7, #T_8a7f7_row0_col8, #T_8a7f7_row0_col9 {
#   border: 1px solid;
# }
# </style>
# <table id="T_8a7f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a7f7_level0_col0" class="col_heading level0 col0" >credit_score</th>
#       <th id="T_8a7f7_level0_col1" class="col_heading level0 col1" >country</th>
#       <th id="T_8a7f7_level0_col2" class="col_heading level0 col2" >gender</th>
#       <th id="T_8a7f7_level0_col3" class="col_heading level0 col3" >age</th>
#       <th id="T_8a7f7_level0_col4" class="col_heading level0 col4" >tenure</th>
#       <th id="T_8a7f7_level0_col5" class="col_heading level0 col5" >balance</th>
#       <th id="T_8a7f7_level0_col6" class="col_heading level0 col6" >products_number</th>
#       <th id="T_8a7f7_level0_col7" class="col_heading level0 col7" >credit_card</th>
#       <th id="T_8a7f7_level0_col8" class="col_heading level0 col8" >active_member</th>
#       <th id="T_8a7f7_level0_col9" class="col_heading level0 col9" >estimated_salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a7f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a7f7_row0_col0" class="data row0 col0" >400</td>
#       <td id="T_8a7f7_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_8a7f7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_8a7f7_row0_col3" class="data row0 col3" >50</td>
#       <td id="T_8a7f7_row0_col4" class="data row0 col4" >3</td>
#       <td id="T_8a7f7_row0_col5" class="data row0 col5" >500.000000</td>
#       <td id="T_8a7f7_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_8a7f7_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_8a7f7_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_8a7f7_row0_col9" class="data row0 col9" >200000.000000</td>
#     </tr>
#   </tbody>
# </table>
# Predicted value:-
#
# Customer is likely to leave
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished

# %% [markdown]
# Saving the model using 'pickle'

# %%
filename = 'final_model.sav'
pickle.dump(rf, open(filename, 'wb'))

# %% [markdown]
# Model has been saved
